# %%
import pandas as pd

df_2017 = pd.read_csv("data/2017.csv")
df_2018 = pd.read_csv("data/2018.csv")
df_2019 = pd.read_csv("data/2020.csv")
df_2020 = pd.read_csv("data/20.csv")
df_2021 = pd.read_csv("data/2021.csv")

# %%
df
# Out:
#             Team            Full Name  Overall Rating Position  Age  Speed  \
# 0           Rams         Aaron Donald              99       RE   29     82
# 1       Patriots      Stephon Gilmore              99       CB   29     92
# 2       Panthers  Christian McCaffrey              99       HB   24     92
# 3         Chiefs      Patrick Mahomes              99       QB   24     81
# 4         Saints       Michael Thomas              99       WR   27     89
# ...          ...                  ...             ...      ...  ...    ...
# 2288    Steelers      Kameron Canaday              26       TE   27     66
# 2289     Jaguars          Matt Orzech              25       TE   25     77
# 2290       Colts          Luke Rhodes              24       TE   27     80
# 2291     Raiders           Trent Sieg              24       TE   24     62
# 2292  Buccaneers          Zach Triner              23       TE   29     77
#
# ...
